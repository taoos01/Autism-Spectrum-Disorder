# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
x = np.array(["Hello" , "World", "Fun", "Fair"])

# %%
print(x)
# Out:
# ['Hello' 'World' 'Fun' 'Fair']

# %%
le = LabelEncoder()

# %%
X = le.fit(x)

# %%
print(X)
# Out:
# LabelEncoder()

# %%
X = le.transform(x)

# %%
X
# Out:
# array([2, 3, 1, 0])

# %%
ethnicity_for_encoding = ['White-European', 'Middle Eastern', 'Pasifika', 'Black', 'Hispanic','Asian', 'Turkish', 'South Asian','Latino','Others']

# %%
le.fit(ethnicity_for_encoding)
# Out:
# LabelEncoder()

# %%
oo = le.transform(ethnicity_for_encoding)

# %%
print(oo)
# Out:
# [9 4 6 1 2 0 8 7 3 5]

# %%
questionnaires = {
        "Avoids eye contact with others." : {"Yes" : 1, "No" : 0},
        "Has trouble understanding other people’s feelings." : {"Yes" : 1, "No" : 0},
        "Prefers to be alone rather than with others." : {"Yes" : 1, "No" : 0},
        "Has unusually intense interests." : {"Yes" : 1, "No" : 0},
        "Has difficulty understanding the back-and-forth flow of normal conversation.." : {"Yes" : 1, "No" : 0},
        "Responds inappropriately to other's attempts at social interaction (e.g., doesn’t answer or walks away)." : {"Yes" : 1, "No" : 0},
        "Shows little interest in playing with other children." : {"Yes" : 1, "No" : 0},
        "Overreacts to minor changes in routine or environment." : {"Yes" : 1, "No" : 0},
        "Focuses intensely on particular topics or interests, often at the exclusion of everything else." : {"Yes" : 1, "No" : 0},
        "Uses unusual tone of voice, pitch, or rhythm when speaking." : {"Yes" : 1, "No" : 0}
    }

questions_list = []
for questions, ans in questionnaires.items():
    answer = ans
    questions_list.append(answer)

print(questions_list)

# for question, ans in questionnaires.items():
#     questions_list.append(ans)  # append the value directly

# print(questions_list)
# Out:
# [{'Yes': 1, 'No': 0}, {'Yes': 1, 'No': 0}, {'Yes': 1, 'No': 0}, {'Yes': 1, 'No': 0}, {'Yes': 1, 'No': 0}, {'Yes': 1, 'No': 0}, {'Yes': 1, 'No': 0}, {'Yes': 1, 'No': 0}, {'Yes': 1, 'No': 0}, {'Yes': 1, 'No': 0}]

# %%
wer = {'southeast' : 0, 'southwest' : 1, 'northwest' : 3, 'northeast': 2}

# %%
wer['southeast']
# Out:
# 0

# %%
# A1_Score,A2_Score,A3_Score,A4_Score,A5_Score,A6_Score,A7_Score,A8_Score,A9_Score,A10_Score,age,gender,ethnicity,jaundice,austim,contry_of_res,used_app_before,result,relation

# %%
le.fit(ethnicityDict)
# Out:
# LabelEncoder()

# %%
X = le.transform(ethnicityDict)

# %%
print(X)
# Out:
# [9 4 6 1 2 0 8 7 3 5]

# %%
ethnicity_dict = {'White-European' : 
    'White-European', 'Middle Eastern' : 'Middle Eastern', 'Pasifika' : 'Pasifika', 'Black' : 'Black', 'Hispanic' : 'Hispanic', 'Asian' : 'Asian', 'Turkish' : 'Turkish', 'South Asian' : 'South Asian', 'Latino' : 'Latino', 'Others' : 'Others'}

# %%
X = list(ethnicity_dict.values())

# %%
X
# Out:
# ['White-European',
#  'Middle Eastern',
#  'Pasifika',
#  'Black',
#  'Hispanic',
#  'Asian',
#  'Turkish',
#  'South Asian',
#  'Latino',
#  'Others']

# %%
le.fit(X)
# Out:
# LabelEncoder()

# %%
Y =le.transform(X)

# %%
print(Y)
# Out:
# [9 4 6 1 2 0 8 7 3 5]

# %%
country_of_res = ['Austria', 'India', 'United States', 'South Africa', 'Jordan','United Kingdom', 'Brazil', 'New Zealand', 'Canada', 'Kazakhstan','United Arab Emirates', 'Australia', 'Ukraine', 'Iraq', 'France','Malaysia', 'Vietnam', 'Egypt', 'Netherlands', 'Afghanistan','Oman', 'Italy', 'Bahamas', 'Saudi Arabia', 'Ireland', 'Aruba','Sri Lanka', 'Russia', 'Bolivia', 'Azerbaijan', 'Armenia','Serbia', 'Ethiopia', 'Sweden', 'Iceland', 'China', 'Angola','Germany', 'Spain', 'Tonga', 'Pakistan', 'Iran', 'Argentina','Japan', 'Mexico', 'Nicaragua', 'Sierra Leone', 'Czech Republic','Niger', 'Romania', 'Cyprus', 'Belgium', 'Burundi', 'Bangladesh']

# %%
len(country_of_res)
# Out:
# 54

# %%
data = {
    "row1": {"fruit": "apple", "color": "red"},
    "row2": {"fruit": "banana", "color": "yellow"},
    "row3": {"fruit": "grape", "color": "green"}
}

# %%
df = pd.DataFrame.from_dict(data, orient="index")
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#         fruit   color
# row1   apple     red
# row2  banana  yellow
# row3   grape   green

# %%
questionnaires = [
    "Avoids eye contact with others.",
    "Has trouble understanding other people’s feelings.",
    "Prefers to be alone rather than with others.",
    "Has unusually intense interests.",
    "Has difficulty understanding the back-and-forth flow of normal conversation..",
    "Responds inappropriately to other's attempts at social interaction (e.g., doesn’t answer or walks away)." ,
    "Shows little interest in playing with other children.",
    "Overreacts to minor changes in routine or environment.",
    "Focuses intensely on particular topics or interests, often at the exclusion of everything else.",
    "Uses unusual tone of voice, pitch, or rhythm when speaking."
]

# %%
yes_no = {"Yes" : 1, "No" : 0}

# %%
for i in questionnaires:
    print(i, random.rand(yes_no))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 import random
#       2 for i in questionnaires:
# ----> 3     print(i, random.random(yes_no))
#
# TypeError: Random.random() takes no arguments (1 given)

# %%
["Do you often find it hard to understand jokes, sarcasm, or figurative language?",
"Do you sometimes repeat words, phrases, or sentences in conversations (echolalia)?"
"Do you struggle to start or maintain a back-and-forth conversation?",
"Do you avoid making eye contact while speaking?",
"Do you find it difficult to judge when it’s your turn to speak in a conversation?",
"Do you often take what people say very literally?",
"Do you find it challenging to explain your thoughts or feelings in words?",
"Do people often tell you that your tone of voice sounds unusual or “flat”?",
"Do you struggle to adjust your way of speaking depending on who you are talking to (e.g., child vs. adult)?",
"Do you often speak at length about your favorite topic, even if the other person isn’t interested?"
]
